# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### import the two data sets & creat one data set
# ###### itoran_df - the info on all the drivies and their behavior
# ###### acc_df - all the driver who did accidinets

# %%
itoran_df = pd.read_csv("C:/Users/elon6/Desktop/לימודים/שנה רביעית/סמסטר ב/MI/data_tomer.csv")
acc_df = pd.read_csv("C:/Users/elon6/Desktop/לימודים/שנה רביעית/סמסטר ב/MI/accidents_tomer.csv")

# %%
itoran_df
# Out:
#       driver_id     key  car_group  total_km  km_road  km_ofroad  \
# 0       2211933  298469       87.0     139.3    139.0        0.3
# 1       6068860     NaN        NaN    3895.8   3767.6      128.2
# 2       8263549  298920       81.0       0.9      0.9        0.0
# 3       4680246     NaN        NaN     312.1    311.0        1.1
# 4       8450000  298851       81.0      62.9     62.9        0.0
# ...         ...     ...        ...       ...      ...        ...
# 7190    9675662     NaN        NaN    2316.3   2211.4      104.9
# 7191    8700935     NaN        NaN    7654.8   7143.5      511.3
# 7192    9153106     NaN        NaN    2056.9   2031.9       25.0
# 7193    7063055     NaN        NaN     121.2    119.5        1.7
# 7194    8000691  515456       95.0       0.0      0.0        0.0
#
#      total_eng_time eng_time_standing eng_time_standing_precent  saftey_grade  \
# 0          02:31:05              0:14                     9.00%           100
# ...

# %%
acc_df
# Out:
#            date  day  unit   unit_type platoon    car_type     key  \
# 0    12/05/2022    5  6930  tranporter      34  tranporter  298471
# 1    01/05/2022    1  6920   mandetory      24       cargo  512110
# 2    24/07/2022    1  6920   mandetory      24       cargo  512148
# 3    29/09/2022    5  6930   mandetory      44       cargo  512080
# 4    27/11/2022    1  6930   mandetory      44       cargo  512050
# ..          ...  ...   ...         ...     ...         ...     ...
# 249  18/09/2022    1  6920   mandetory      24       cargo  512041
# 250  27/07/2022    4  6930  tranporter      33        semi  298868
# 251  23/05/2022    2  6920   mandetory      24       cargo  512066
# 252  18/01/2022    3  6910  tranporter      14  tranporter  298449
# 253  01/05/2022    1  6910  tranporter      14  tranporter  298483
#
#     driver_type  driver_id  fault   decription  Inside_base
# 0       citizen  909800251      0          NaN            0
# ...

# %%
itoran_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7195 entries, 0 to 7194
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   driver_id                  7195 non-null   int64
#  1   key                        4614 non-null   object
#  2   car_group                  4614 non-null   float64
#  3   total_km                   7195 non-null   float64
#  4   km_road                    7195 non-null   float64
#  5   km_ofroad                  7195 non-null   float64
#  6   total_eng_time             7195 non-null   object
#  7   eng_time_standing          6197 non-null   object
#  8   eng_time_standing_precent  7195 non-null   object
#  9   saftey_grade               7195 non-null   int64
#  10  Fuel_economy_grade         7195 non-null   int64
#  11  braking                    3098 non-null   float64
#  12  turns                      2746 non-null   float64
# ...

# %%
acc_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         254 non-null    object
#  1   day          254 non-null    int64
#  2   unit         254 non-null    object
#  3   unit_type    254 non-null    object
#  4   platoon      245 non-null    object
#  5   car_type     252 non-null    object
#  6   key          254 non-null    object
#  7   driver_type  254 non-null    object
#  8   driver_id    254 non-null    int64
#  9   fault        254 non-null    int64
#  10  decription   101 non-null    object
#  11  Inside_base  254 non-null    int64
# dtypes: int64(4), object(8)
# memory usage: 23.9+ KB

# %%
from pandas_profiling import ProfileReport
# Out:
# C:\Users\keren\AppData\Local\Temp/ipykernel_13276/3063248848.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
len(itoran_df.car_group.unique().tolist())
# Out:
# 23

# %% [markdown]
# merge the two data set, left join (keep all the data from the itoran_df) using driver_id

# %%
merged_df = pd.merge(itoran_df, acc_df, on='driver_id', how='left')
merged_df
# Out:
#       driver_id   key_x  car_group  total_km  km_road  km_ofroad  \
# 0       2211933  298469       87.0     139.3    139.0        0.3
# 1       6068860     NaN        NaN    3895.8   3767.6      128.2
# 2       8263549  298920       81.0       0.9      0.9        0.0
# 3       4680246     NaN        NaN     312.1    311.0        1.1
# 4       8450000  298851       81.0      62.9     62.9        0.0
# ...         ...     ...        ...       ...      ...        ...
# 7253    9675662     NaN        NaN    2316.3   2211.4      104.9
# 7254    8700935     NaN        NaN    7654.8   7143.5      511.3
# 7255    9153106     NaN        NaN    2056.9   2031.9       25.0
# 7256    7063055     NaN        NaN     121.2    119.5        1.7
# 7257    8000691  515456       95.0       0.0      0.0        0.0
#
#      total_eng_time eng_time_standing eng_time_standing_precent  saftey_grade  \
# 0          02:31:05              0:14                     9.00%           100
# ...

# %%
merged_df.drop(['key_x'], axis=1, inplace=True)

# %%
merged_df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'driver_id',
#  'car_group',
#  'total_km',
#  'km_road',
#  'km_ofroad',
#  'total_eng_time',
#  'eng_time_standing',
#  'eng_time_standing_precent',
#  'saftey_grade',
#  'Fuel_economy_grade',
#  'braking',
#  'turns',
#  'lane_crossing',
#  'Speed_?deviations',
#  'acceleration',
#  'Special_evants',
#  'fault']

# %%
merged_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6824 entries, 0 to 6823
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 6824 non-null   int64
#  1   driver_id                  6824 non-null   int64
#  2   car_group                  4398 non-null   float64
#  3   total_km                   6824 non-null   float64
#  4   km_road                    6824 non-null   float64
#  5   km_ofroad                  6824 non-null   float64
#  6   total_eng_time             6824 non-null   object
#  7   eng_time_standing          5849 non-null   object
#  8   eng_time_standing_precent  6824 non-null   object
#  9   saftey_grade               6824 non-null   int64
#  10  Fuel_economy_grade         6824 non-null   int64
#  11  braking                    2854 non-null   float64
#  12  turns                      2515 non-null   float64
# ...
